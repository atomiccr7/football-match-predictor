# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_excel("Financial Sample.xlsx")

# %%
dataset.sample(10)
# Out:
#               Segment                   Country    Product DiscountBand  \
# 160  Channel Partners  United States of America      Paseo          Low
# 59         Government                    Mexico  Carretera          Low
# 154        Enterprise                   Germany    Montana          Low
# 676        Enterprise                   Germany      Paseo         High
# 240        Government  United States of America      Paseo       Medium
# 70         Government                    France    Montana          Low
# 461        Enterprise  United States of America    Montana         High
# 178         Midmarket                    France      Paseo          Low
# 435        Enterprise                    Mexico        VTT       Medium
# 22          Midmarket                    France      Paseo          NaN
#
#       Units  Manufacturing  SalePrice  Gross Sales  Discounts      Sales  \
# 160  1369.5           10.0       12.0      16434.0     493.02   15940.98
# 59   1210.0            3.0      350.0     423500.0    4235.00  419265.00
# 154  1706.0            5.0      125.0     213250.0    6397.50  206852.50
# 676  1085.0           10.0      125.0     135625.0   20343.75  115281.25
# 240  2327.0           10.0        7.0      16289.0     814.45   15474.55
# 70   1375.5            5.0       20.0      27510.0     275.10   27234.90
# 461  1804.0            5.0      125.0     225500.0   22550.00  202950.00
# 178  2261.0           10.0       15.0      33915.0    1356.60   32558.40
# 435   877.0          250.0      125.0     109625.0    9866.25   99758.75
# 22      NaN           10.0       15.0       8235.0       0.00    8235.00
#
#          COGS     Profit       Date  Month Number Month Name  Year
# 160    4108.5   11832.48 2014-07-01             7       July  2014
# 59   314600.0  104665.00 2014-03-01             3      March  2014
# 154  204720.0    2132.50 2014-12-01            12   December  2014
# 676  130200.0  -14918.75 2014-10-01            10    October  2014
# 240   11635.0    3839.55 2014-05-01             5        May  2014
# 70    13755.0   13479.90 2014-07-01             7       July  2014
# 461  216480.0  -13530.00 2013-11-01            11   November  2013
# 178   22610.0    9948.40 2013-12-01            12   December  2013
# 435  105240.0   -5481.25 2014-11-01            11   November  2014
# 22     5490.0    2745.00 2013-09-01             9  September  2013

# %%
dataset.shape
# Out:
# (700, 16)

# %%
dataset.shape[0]
# Out:
# 700

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(188)

# %%
(dataset.notnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# np.float64(98.32142857142857)

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# np.float64(1.6785714285714286)

# %%
dataset.isnull().sum()
# Out:
# Segment           0
# Country           0
# Product           0
# DiscountBand     53
# Units            30
# Manufacturing    16
# SalePrice        11
# Gross Sales      22
# Discounts         9
# Sales            20
# COGS             11
# Profit           16
# Date              0
# Month Number      0
# Month Name        0
# Year              0
# dtype: int64

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# Segment          0.000000
# Country          0.000000
# Product          0.000000
# DiscountBand     7.571429
# Units            4.285714
# Manufacturing    2.285714
# SalePrice        1.571429
# Gross Sales      3.142857
# Discounts        1.285714
# Sales            2.857143
# COGS             1.571429
# Profit           2.285714
# Date             0.000000
# Month Number     0.000000
# Month Name       0.000000
# Year             0.000000
# dtype: float64

# %%
sns.heatmap(dataset.isnull())
plt.show()
