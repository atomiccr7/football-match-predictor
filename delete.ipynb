# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel("Financial Sample.xlsx")
dataset.sample(4)
# Out:
#         Segment Country   Product DiscountBand   Units  Manufacturing  \
# 663  Government  France  Amarilla         High  1731.0          260.0
# 269  Government  Canada  Amarilla       Medium   552.0          260.0
# 319  Government  Canada      Velo       Medium  1135.0          120.0
# 661   Midmarket  Canada  Amarilla         High  1743.0          260.0
#
#      SalePrice  Gross Sales  Discounts      Sales      COGS    Profit  \
# 663        7.0      12117.0    1696.38   10420.62    8655.0   1765.62
# 269      350.0     193200.0    9660.00  183540.00  143520.0  40020.00
# 319        7.0       7945.0     556.15    7388.85    5675.0   1713.85
# 661       15.0      26145.0    3660.30   22484.70   17430.0   5054.70
#
#           Date  Month Number Month Name  Year
# 663 2014-10-01            10    October  2014
# 269 2014-08-01             8     August  2014
# 319 2014-06-01             6       June  2014
# 661 2013-10-01            10    October  2013

# %%
dataset.shape
# Out:
# (577, 15)

# %%
dataset.shape
# Out:
# (577, 15)

# %%
((701-577)/701)*100
# Out:
# 17.68901569186876

# %%
dataset.isnull().sum()
# Out:
# Segment          0
# Country          0
# Product          0
# Units            0
# Manufacturing    0
# SalePrice        0
# Gross Sales      0
# Discounts        0
# Sales            0
# COGS             0
# Profit           0
# Date             0
# Month Number     0
# Month Name       0
# Year             0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %%
dataset.drop(columns=["DiscountBand"],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 dataset.drop(columns=["DiscountBand"],inplace=True)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
dataset.dropna(inplace=True)
