# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_excel("Financial Sample.xlsx")

# %%
dataset.sample(3)
# Out:
#               Segment                   Country Product DiscountBand   Units  \
# 160  Channel Partners  United States of America   Paseo          Low  1369.5
# 238        Enterprise                    France   Paseo       Medium  2385.0
# 603  Channel Partners                    Mexico    Velo         High   410.0
#
#      Manufacturing  SalePrice  Gross Sales  Discounts      Sales      COGS  \
# 160             10         12      16434.0     493.02   15940.98    4108.5
# 238             10        125     298125.0   14906.25  283218.75  286200.0
# 603            120         12       4920.0     639.60    4280.40    1230.0
#
#        Profit       Date  Month Number Month Name  Year
# 160  11832.48 2014-07-01             7       July  2014
# 238  -2981.25 2014-03-01             3      March  2014
# 603   3050.40 2014-10-01            10    October  2014

# %%
dataset['Units'].var()
# Out:
# 752431.0906683011

# %%
sns.histplot(x="Units",data=dataset)
# Out:
# <Axes: xlabel='Units', ylabel='Count'>

# %%
sec_a = np.array([75,65,73,68,72,76])
sec_b = np.array([90,47,43,96,93,51])
no = np.array([1,2,3,4,5,6])

# %%
np.std(sec_a),np.std(sec_b)
# Out:
# (np.float64(3.8622100754188224), np.float64(23.18045153428495))

# %%
np.var(sec_a),np.var(sec_b)
# Out:
# (np.float64(14.916666666666666), np.float64(537.3333333333334))

# %%
mean = np.mean(sec_b)
mean
# Out:
# np.float64(70.0)

# %%
mad_a = np.sum(np.abs(sec_a - mean))/len(sec_a)
mad_b = np.sum(np.abs(sec_b - mean))/len(sec_b)

# %%
mad_a,mad_b
# Out:
# (np.float64(3.8333333333333335), np.float64(23.0))

# %%
plt.figure(figsize=(10,3))
plt.scatter(sec_a,no,label="sec_a")
plt.scatter(sec_b,no,c="red",label="sec_b")
plt.plot([70,70,70,70,70,70],no,c="blue",label="mean")
plt.legend()
plt.show()
