# %%
import scipy.stats as st
import numpy as np

# %%
t_table = st.t.ppf(0.4,19)
t_table
# Out:
# np.float64(-0.25692281979615467)

# %%
Before = np.array([78,84,92,88,75,80,85,90,87,79,78,84,92,88,75,80,85,90,87,79])
After = np.array([82,88,75,90,78,85,88,77,92,80,82,88,75,90,78,85,88,77,92,80])

# %%
std_a = np.std(A)
std_b = np.std(B)
mean_a = np.mean(A)
mean_b = np.mean(B)

# %%
t_cal = (mean_b-mean_a) / (np.sqrt(((std_b*std_b)/len(B))+((std_a*std_a)/len(A))))
t_cal
# Out:
# np.float64(-0.1731906488041254)
